# %%
import scipy.stats
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
np.random.seed(1234)
binom_samples = np.random.binomial(10,0.65,1000)
cond_vars = []
for i in range(0,5):
    cond_vars.append(np.random.standard_normal(1000))
z = []
for a,b,c,d,e in zip(cond_vars[0],cond_vars[1],cond_vars[2],cond_vars[3],cond_vars[4]):
    z.append(a+b+c+d+e)

samples = z
# samples=np.random.lognormal(mean=1.,sigma=.4,size=10000)
print(samples)
# shape,loc,scale=scipy.stats.lognorm.fit(,floc=0)
num_bins=50
clr="#EFEFEF"

counts,edges,patches=plt.hist(samples,bins=num_bins,color=clr)
test = np.random.lognormal(0,1,1000)

plt.show()

plt.hist(test)
plt.show()
# centers=0.5*(edges[:-1]+edges[1:])
# pdf = scipy.stats.norm.pdf(samples)
# # cdf=scipy.stats.norm.cdf(edges,shape,loc=loc,scale=scale)
# prob=np.diff(cdf)
# plt.plot(centers,samples.size*prob,'k-',linewidth=2)
# Out:
# [1.825874907650567, -2.42959667289969, 2.306479014958602, -1.8991123572574429, -0.757771068234298, 2.323650949031843, 0.7490555179383368, -3.31982496055741, -1.0623204571737284, 0.9802064774510122, -3.4971557657677073, 0.7030044067999324, -5.273242943264116, 0.24385153279876942, 1.6702096637709034, 2.076826425837872, 0.845261625445114, -2.920339488394604, 0.17582543794094052, -6.03455974282964, 0.046110986440626556, 3.727282381255371, 0.6846141782093733, -0.7959270727746459, -1.8404835225311116, 1.2746815398081375, 4.1590499234167595, -1.9948644157165312, -2.562787486898733, 0.796835763973907, -1.4060722334370874, 0.11859051872269688, 2.4712201859408327, -2.323005003046174, 1.995971114443848, 3.1168744728317783, 0.04094569806305559, 4.0890858314557255, 4.386318547040968, -1.0781525805136938, -1.3066752896148817, -1.839929415872668, 0.5907894074478022, 0.25256551149036255, 1.0669516801158343, 2.5843270106205836, -5.020439751184705, -3.490619753764814, 0.4903292144220136, 0.65046414063
# ...
